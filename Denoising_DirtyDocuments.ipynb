# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Tue Nov 26 14:06:08 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.33.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P0    88W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import glob
import torch
import torch.nn as nn
import torch.utils as utils
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torchvision.utils import save_image
import numpy as np
import matplotlib.pyplot as plt
from numpy import newaxis

import imgaug as ia
from imgaug import augmenters as iaa
from skimage import io, transform

# %%
# import warnings
# warnings.filterwarnings("ignore")
# plt.ion()

# %%
class DirtyDocumentsDataset(Dataset):
    def __init__(self, dirty_dir, clean_dir, transform=None):
        self.dirty_dir = dirty_dir
        self.clean_dir = clean_dir
        self.transform = transform
    
    def __len__(self):
        return len(os.listdir(self.dirty_dir))
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
            
        train_names = sorted(glob.glob(self.dirty_dir + "*.png"))
        train_image = io.imread(train_names[idx], as_gray=True)

        clean_names = sorted(glob.glob(self.clean_dir + "*.png"))
        clean_image = io.imread(clean_names[idx], as_gray=True)

        train_image = train_image[:,:,newaxis]
        clean_image = clean_image[:,:,newaxis]

        sample = { 'train_image' : train_image, 'clean_image':clean_image}

        if self.transform:
           sample = self.transform(sample)

        return sample

# %%
class DirtyDocumentsDataset_Test(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
    
    def __len__(self):
        return len(os.listdir(self.root_dir))
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_names = sorted(glob.glob(self.root_dir + "*.png"))
        img_name = img_names[idx]
        image = io.imread(img_name)

        image = image[:,:,newaxis]

        sample = { 'image' : image}

        if self.transform:
           sample = self.transform(sample)

        return sample

# %%
# Test Loader Transform classes
class Rescale_Test(object):
    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size
    
    def __call__(self, sample):
        image = sample['image']

        h, w = image.shape[:2]
        if isinstance(self.output_size, int):
            if h > self.output_size:
                new_h = self.output_size
            else:
                new_h = self.output_size
        else:
            new_h, new_w = self.output_size
        
        img = transform.resize(image, (new_h,new_w))

        return {'image':img}
    
class ToTensor_Test(object):
    def __call__(self, sample):
        image = sample['image']

        image = image.transpose((2,0,1))
        return { 'image' : torch.from_numpy(image)}

# %%
# Train Loader Transfrom classes
class Rescale(object):
    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size
    
    def __call__(self, sample):
        train_image = sample['train_image']
        clean_image = sample['clean_image']

        h, w = train_image.shape[:2]
        if isinstance(self.output_size, int):
            if h > self.output_size:
                new_h = self.output_size
            else:
                new_h = self.output_size
        else:
            new_h, new_w = self.output_size
        
        tr_img = transform.resize(train_image, (new_h,new_w))
        cl_img = transform.resize(clean_image, (new_h,new_w))

        return {'train_image':tr_img, 'clean_image':cl_img}
    
class ToTensor(object):
    def __call__(self, sample):
        train_image = sample['train_image']
        clean_image = sample['clean_image']

        train_image = train_image.transpose((2,0,1))
        clean_image = clean_image.transpose((2,0,1))
        return { 'train_image' : torch.from_numpy(train_image),'clean_image' : torch.from_numpy(clean_image)}

class RandomCrop:
    def __init__(self, size, threshold):
        assert isinstance(size,(tuple))
        self.size = size
        self.threshold = threshold

    def __call__(self, sample):
        p = np.random.rand(1)

        if p <= self.threshold:
            clean_image = sample['clean_image']
            dirty_image = sample['train_image']

            clean_img = np.array(clean_image)
            dirty_img = np.array(dirty_image)

            x, y = clean_img.shape[:2]

            x = x - 1 - self.size[0]
            y = y - 1 - self.size[1]
            min_x = int(np.random.rand(1) * x)
            min_y = int(np.random.rand(1) * y)
            max_x = min_x + self.size[0]
            max_y = min_y + self.size[1]

            clean_crop = clean_img[min_x:max_x, min_y:max_y]
            dirty_crop = dirty_img[min_x:max_x, min_y:max_y]
        else:
            clean_crop = sample['clean_image']
            dirty_crop = sample['train_image']

        return {'clean_image' : clean_crop, 'train_image' : dirty_crop}

class ImgAugTransform:
    def __init__(self):
        self.sometimes = lambda aug: iaa.Sometimes(0.25,aug)
        self.aug = iaa.Sequential([
            self.sometimes(iaa.GaussianBlur(sigma=(0,3.0)))
        ])

    def __call__(self, sample):
        clean_image = sample['clean_image']
        dirty_image = sample['train_image']

        clean_img = np.array(clean_image)
        dirty_img = np.array(dirty_image)

        return {'clean_image' : clean_img, 'train_image' : self.aug.augment_image(dirty_img)}

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(1,8,3,padding=1),
            nn.BatchNorm2d(8),     # batch x 8 x 256 x 540
            nn.ReLU(),
            nn.Conv2d(8,16,3,padding=1),
            nn.BatchNorm2d(16),    # batch x 16 x 256 x 540
            nn.ReLU(),
            nn.Conv2d(16,32,3,padding=1),
            nn.BatchNorm2d(32),   # batch x 32 x 256 x 540
            nn.ReLU(),
            nn.Conv2d(32,64,3,padding=1),
            nn.BatchNorm2d(64),   # batch x 64 x 256 x 540
            nn.ReLU(),
            nn.MaxPool2d(2,2)     # batch x 64 x 128 x 270
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64,128,3,padding=1),
            nn.BatchNorm2d(128),  # batch x 64 x 128 x 270
            nn.ReLU(),
            nn.Conv2d(128,128,3,padding=1),
            nn.BatchNorm2d(128), # batch x 128 x 128 x 270
            nn.ReLU(),
            nn.MaxPool2d(2,2),   # batch x 128 x 64x 135
            nn.Conv2d(128,256,3,padding=1), # batch x 256 x 64 x 135
            nn.ReLU(),
            #nn.BatchNorm2d(256)
        )

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        # out = out.view(batch_size, -1)
        return out

# %%
class Decoder(nn.Module):
    def __init__(self):
        super(Decoder,self).__init__()
        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(256,128,3,2,padding=1,output_padding=1),# batch * 128 * 128 * 270
            nn.BatchNorm2d(128), 
            nn.ReLU(),
            nn.ConvTranspose2d(128,128,3,1,1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.ConvTranspose2d(128,64,3,1,1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.ConvTranspose2d(64,32,3,1,1),
            nn.BatchNorm2d(32),
            nn.ReLU()
        )
        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(32,16,3,1,1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.ConvTranspose2d(16,8,3,1,1),
            nn.BatchNorm2d(8),
            nn.ReLU(),
            nn.ConvTranspose2d(8,1,3,2,1,1),
            nn.ReLU()
        )
    
    def forward(self, x):
        # out = x.view(batch_size,256,65,135)
        out = self.layer1(x)
        out = self.layer2(out)
        return out

# %%
# Set Hyperparameters and DataLoader

epoch = 1000
batch_size = 20
learning_rate = 0.0005

composed_test = transforms.Compose([ Rescale_Test((256,540)), ToTensor_Test()])
composed = transforms.Compose([ImgAugTransform(), RandomCrop((256,256),0.25),Rescale((256,540)),ToTensor()])

root_dir = "./drive/My Drive/Colab Notebooks/Denoising_test/"

train_dataset = DirtyDocumentsDataset(dirty_dir=root_dir+"train/",clean_dir=root_dir+"train_cleaned/", transform=composed)
test_dataset = DirtyDocumentsDataset_Test(root_dir=root_dir+"test/", transform=composed_test)

train_loader = DataLoader(dataset=train_dataset, batch_size= batch_size)
test_loader = DataLoader(dataset=test_dataset, batch_size= batch_size)

encoder = Encoder().cuda()
decoder = Decoder().cuda()

# %%
# loss func and optimizer

parameters = list(encoder.parameters())+ list(decoder.parameters())
loss_func = nn.MSELoss()
optimizer = torch.optim.Adam(parameters, lr=learning_rate)

# %%
# train encoder and decoder

# try:
#     encoder, decoder = torch.load('./drive/My Drive/Colab Notebooks/Denoising_test/models/denoising_autoencoder_1000.pkl')
#     print("\n--------model restored--------\n")
# except:
#     pass

# %%
min_loss = 1

for i in range(epoch):
    for image_pair in train_loader:
        train_image = image_pair['train_image']
        train_image = Variable(train_image.float()).cuda()
        clean_image = image_pair['clean_image']
        clean_image = Variable(clean_image.float()).cuda()

        optimizer.zero_grad()

        output = encoder(train_image)
        output = decoder(output)

        loss = loss_func(output,clean_image)
        loss.backward()
        optimizer.step()
    
    if min_loss > loss:
        torch.save([encoder,decoder],'./drive/My Drive/Colab Notebooks/Denoising_test/models/denoising_autoencoder_test1.pkl')
        min_loss = loss
    
    #save_image(output[3,:,:,:],'./drive/My Drive/Colab Notebooks/model/training/{}.png'.format(i))
    # Sam is the number of the last batch

    print("Epoch ", i, ": ", loss)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Encoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BatchNorm2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type MaxPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Decoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ConvTranspose2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch  0 :  tensor(0.2262, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  1 :  tensor(0.1816, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  2 :  tensor(0.1522, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  3 :  tensor(0.1320, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  4 :  tensor(0.1170, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  5 :  tensor(0.0993, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  6 :  tensor(0.0885, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  7 :  tensor(0.0712, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  8 :  tensor(0.0677, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  9 :  tensor(0.0645, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  10 :  tensor(0.0514, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  11 :  tensor(0.0492, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  12 :  tensor(0.0408, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  13 :  tensor(0.0401, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  14 :  tensor(0.0379, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  15 :  tensor(0.0378, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  16 :  tensor(0.0402, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  17 :  tensor(0.0385, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  18 :  tensor(0.0363, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  19 :  tensor(0.0333, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  20 :  tensor(0.0319, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  21 :  tensor(0.0335, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  22 :  tensor(0.0354, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  23 :  tensor(0.0333, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  24 :  tensor(0.0327, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  25 :  tensor(0.0313, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  26 :  tensor(0.0322, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  27 :  tensor(0.0299, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  28 :  tensor(0.0295, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  29 :  tensor(0.0273, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  30 :  tensor(0.0314, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  31 :  tensor(0.0278, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  32 :  tensor(0.0282, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  33 :  tensor(0.0292, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  34 :  tensor(0.0260, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  35 :  tensor(0.0281, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  36 :  tensor(0.0285, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  37 :  tensor(0.0267, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  38 :  tensor(0.0252, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  39 :  tensor(0.0305, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  40 :  tensor(0.0303, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  41 :  tensor(0.0298, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  42 :  tensor(0.0290, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  43 :  tensor(0.0271, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  44 :  tensor(0.0260, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  45 :  tensor(0.0281, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  46 :  tensor(0.0257, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  47 :  tensor(0.0274, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  48 :  tensor(0.0260, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  49 :  tensor(0.0252, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  50 :  tensor(0.0264, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  51 :  tensor(0.0273, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  52 :  tensor(0.0310, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  53 :  tensor(0.0267, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  54 :  tensor(0.0245, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  55 :  tensor(0.0245, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  56 :  tensor(0.0248, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  57 :  tensor(0.0280, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  58 :  tensor(0.0254, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  59 :  tensor(0.0244, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  60 :  tensor(0.0255, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  61 :  tensor(0.0268, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  62 :  tensor(0.0273, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  63 :  tensor(0.0270, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  64 :  tensor(0.0264, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  65 :  tensor(0.0239, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  66 :  tensor(0.0272, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  67 :  tensor(0.0275, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  68 :  tensor(0.0261, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  69 :  tensor(0.0250, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  70 :  tensor(0.0233, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  71 :  tensor(0.0230, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  72 :  tensor(0.0229, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  73 :  tensor(0.0230, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  74 :  tensor(0.0239, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  75 :  tensor(0.0215, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  76 :  tensor(0.0221, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  77 :  tensor(0.0258, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  78 :  tensor(0.0230, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  79 :  tensor(0.0223, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  80 :  tensor(0.0231, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  81 :  tensor(0.0244, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  82 :  tensor(0.0224, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  83 :  tensor(0.0228, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  84 :  tensor(0.0220, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  85 :  tensor(0.0212, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  86 :  tensor(0.0223, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  87 :  tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  88 :  tensor(0.0243, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  89 :  tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  90 :  tensor(0.0213, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  91 :  tensor(0.0208, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  92 :  tensor(0.0252, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  93 :  tensor(0.0200, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  94 :  tensor(0.0231, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  95 :  tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  96 :  tensor(0.0272, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  97 :  tensor(0.0218, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  98 :  tensor(0.0225, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  99 :  tensor(0.0229, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  100 :  tensor(0.0206, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  101 :  tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  102 :  tensor(0.0223, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  103 :  tensor(0.0222, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  104 :  tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  105 :  tensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  106 :  tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  107 :  tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  108 :  tensor(0.0213, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  109 :  tensor(0.0198, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  110 :  tensor(0.0210, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  111 :  tensor(0.0215, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  112 :  tensor(0.0209, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  113 :  tensor(0.0257, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  114 :  tensor(0.0235, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  115 :  tensor(0.0224, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  116 :  tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  117 :  tensor(0.0217, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  118 :  tensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  119 :  tensor(0.0199, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  120 :  tensor(0.0236, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  121 :  tensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  122 :  tensor(0.0212, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  123 :  tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  124 :  tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  125 :  tensor(0.0224, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  126 :  tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  127 :  tensor(0.0231, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  128 :  tensor(0.0198, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  129 :  tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  130 :  tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  131 :  tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  132 :  tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  133 :  tensor(0.0224, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  134 :  tensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  135 :  tensor(0.0252, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  136 :  tensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  137 :  tensor(0.0198, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  138 :  tensor(0.0215, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  139 :  tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  140 :  tensor(0.0212, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  141 :  tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  142 :  tensor(0.0210, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  143 :  tensor(0.0187, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  144 :  tensor(0.0254, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  145 :  tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  146 :  tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  147 :  tensor(0.0199, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  148 :  tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  149 :  tensor(0.0209, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  150 :  tensor(0.0274, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  151 :  tensor(0.0228, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  152 :  tensor(0.0216, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  153 :  tensor(0.0209, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  154 :  tensor(0.0187, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  155 :  tensor(0.0221, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  156 :  tensor(0.0229, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  157 :  tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  158 :  tensor(0.0183, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  159 :  tensor(0.0225, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  160 :  tensor(0.0210, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  161 :  tensor(0.0230, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  162 :  tensor(0.0210, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  163 :  tensor(0.0225, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  164 :  tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  165 :  tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  166 :  tensor(0.0199, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  167 :  tensor(0.0228, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  168 :  tensor(0.0261, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  169 :  tensor(0.0206, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  170 :  tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  171 :  tensor(0.0211, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  172 :  tensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  173 :  tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  174 :  tensor(0.0178, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  175 :  tensor(0.0184, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  176 :  tensor(0.0215, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  177 :  tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  178 :  tensor(0.0191, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  179 :  tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  180 :  tensor(0.0226, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  181 :  tensor(0.0183, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  182 :  tensor(0.0181, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  183 :  tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  184 :  tensor(0.0251, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  185 :  tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  186 :  tensor(0.0186, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  187 :  tensor(0.0186, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  188 :  tensor(0.0231, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  189 :  tensor(0.0191, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  190 :  tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  191 :  tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  192 :  tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  193 :  tensor(0.0211, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  194 :  tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  195 :  tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  196 :  tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  197 :  tensor(0.0199, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  198 :  tensor(0.0186, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  199 :  tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  200 :  tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  201 :  tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  202 :  tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  203 :  tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  204 :  tensor(0.0183, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  205 :  tensor(0.0178, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  206 :  tensor(0.0250, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  207 :  tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  208 :  tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  209 :  tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  210 :  tensor(0.0200, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  211 :  tensor(0.0213, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  212 :  tensor(0.0166, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  213 :  tensor(0.0210, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  214 :  tensor(0.0168, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  215 :  tensor(0.0208, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  216 :  tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  217 :  tensor(0.0188, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  218 :  tensor(0.0185, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  219 :  tensor(0.0221, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  220 :  tensor(0.0217, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  221 :  tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  222 :  tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  223 :  tensor(0.0166, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  224 :  tensor(0.0251, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  225 :  tensor(0.0189, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  226 :  tensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  227 :  tensor(0.0176, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  228 :  tensor(0.0184, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  229 :  tensor(0.0174, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  230 :  tensor(0.0172, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  231 :  tensor(0.0171, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  232 :  tensor(0.0168, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  233 :  tensor(0.0212, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  234 :  tensor(0.0166, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  235 :  tensor(0.0158, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  236 :  tensor(0.0161, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  237 :  tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  238 :  tensor(0.0188, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  239 :  tensor(0.0198, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  240 :  tensor(0.0206, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  241 :  tensor(0.0173, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  242 :  tensor(0.0171, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  243 :  tensor(0.0172, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  244 :  tensor(0.0176, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  245 :  tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  246 :  tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  247 :  tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  248 :  tensor(0.0152, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  249 :  tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  250 :  tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  251 :  tensor(0.0191, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  252 :  tensor(0.0184, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  253 :  tensor(0.0211, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  254 :  tensor(0.0162, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  255 :  tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  256 :  tensor(0.0157, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  257 :  tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  258 :  tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  259 :  tensor(0.0163, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  260 :  tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  261 :  tensor(0.0168, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  262 :  tensor(0.0172, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  263 :  tensor(0.0188, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  264 :  tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  265 :  tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  266 :  tensor(0.0183, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  267 :  tensor(0.0170, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  268 :  tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  269 :  tensor(0.0172, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  270 :  tensor(0.0227, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  271 :  tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  272 :  tensor(0.0185, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  273 :  tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  274 :  tensor(0.0178, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  275 :  tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  276 :  tensor(0.0187, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  277 :  tensor(0.0185, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  278 :  tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  279 :  tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  280 :  tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  281 :  tensor(0.0183, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  282 :  tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  283 :  tensor(0.0185, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  284 :  tensor(0.0184, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  285 :  tensor(0.0155, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  286 :  tensor(0.0148, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  287 :  tensor(0.0188, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  288 :  tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  289 :  tensor(0.0152, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  290 :  tensor(0.0159, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  291 :  tensor(0.0153, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  292 :  tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  293 :  tensor(0.0193, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  294 :  tensor(0.0152, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  295 :  tensor(0.0150, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  296 :  tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  297 :  tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  298 :  tensor(0.0148, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  299 :  tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  300 :  tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  301 :  tensor(0.0168, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  302 :  tensor(0.0159, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  303 :  tensor(0.0148, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  304 :  tensor(0.0139, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  305 :  tensor(0.0142, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  306 :  tensor(0.0216, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  307 :  tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  308 :  tensor(0.0175, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  309 :  tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  310 :  tensor(0.0172, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  311 :  tensor(0.0143, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  312 :  tensor(0.0185, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  313 :  tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  314 :  tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  315 :  tensor(0.0160, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  316 :  tensor(0.0142, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  317 :  tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  318 :  tensor(0.0153, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  319 :  tensor(0.0168, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  320 :  tensor(0.0171, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  321 :  tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  322 :  tensor(0.0156, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  323 :  tensor(0.0211, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  324 :  tensor(0.0144, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  325 :  tensor(0.0156, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  326 :  tensor(0.0138, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  327 :  tensor(0.0226, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  328 :  tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  329 :  tensor(0.0155, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  330 :  tensor(0.0158, device='cuda:0', grad_fn=<MseLossBackward>)
# Epoch  331 :  tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward>)

# %%
# test encoder and decoder

try:
    encoder, decoder = torch.load('./drive/My Drive/Colab Notebooks/Denoising_test/models/denoising_autoencoder_test1.pkl')
    print("\n--------model loaded--------\n")
    flag = 0
except:
    print("\nmodel does not exist\n")
    flag = 1

test_loader = DataLoader(dataset=test_dataset, batch_size= 10)

if flag == 0:
    j = 0
    for image_test in test_loader:
        image_test = image_test['image']
        image_test = Variable(image_test.float()).cuda()

        output = encoder(image_test)
        output = decoder(output)

        for i in range(image_test.size(0)):
            save_image(image_test[i,:,:,:],'./drive/My Drive/Colab Notebooks/Denoising_test/test_results/test/{}.png'.format(j*batch_size+i))
        for i in range(output.size(0)):
            save_image(output[i,:,:,:],'./drive/My Drive/Colab Notebooks/Denoising_test/test_results/output_test1/{}.png'.format(j*batch_size+i))

        # for inp, out in zip(image_test, output):
        #     inp = inp.cpu()
        #     inp = inp.data.numpy()
        #     plt.title("Test Sample #{}".format(i))
        #     plt.imshow(inp[0],cmap='gray')
        #     plt.show()

        #     out = out.cpu()
        #     out = out.data.numpy()
        #     plt.title("Output Sample #{}".format(i))
        #     plt.imshow(out[0],cmap='gray')
        #     plt.show()

        #     i = i +1
        j= j + 1
